# %% [markdown]
# # Phase 1: Prepare the VTI dataset
#
#                 Notebook này không cố làm mọi thứ trong một ô.
#                 Nó gọi các hàm đã được đóng gói trong `src/vti_repro/`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd() if (Path.cwd() / "src").exists() else Path.cwd().parent
sys.path.insert(0, str(ROOT / "src"))

from vti_repro.data_prep import prepare_vti_dataset

# %% [markdown]
# Chạy trước trên sample nhỏ để kiểm tra mapping nhãn, split, và schema.
#                 Khi đã ổn, tăng dần `max_rows` hoặc bỏ hẳn để chạy full.

# %%
summary = prepare_vti_dataset(
    raw_csv_path=ROOT / "MSR_data_cleaned.csv",
    output_dir=ROOT / "artifacts" / "data_sample",
    seed=42,
    max_rows=20_000,
    report_every=2_000,
)
summary
# Out:
# [prepare_vti_dataset] kept=2000 processed=2100 split={'train': 1589, 'val': 201, 'test': 210}
# [prepare_vti_dataset] kept=4000 processed=5080 split={'train': 3184, 'val': 411, 'test': 405}
# [prepare_vti_dataset] kept=6000 processed=7120 split={'train': 4806, 'val': 620, 'test': 574}
# [prepare_vti_dataset] kept=8000 processed=9202 split={'train': 6368, 'val': 829, 'test': 803}
# [prepare_vti_dataset] kept=10000 processed=11449 split={'train': 7949, 'val': 1023, 'test': 1028}
# [prepare_vti_dataset] kept=12000 processed=13716 split={'train': 9540, 'val': 1223, 'test': 1237}
# [prepare_vti_dataset] kept=14000 processed=15975 split={'train': 11180, 'val': 1377, 'test': 1443}
# [prepare_vti_dataset] kept=16000 processed=18488 split={'train': 12799, 'val': 1557, 'test': 1644}
# {'seed': 42,
#  'raw_csv_path': '/Users/ldt/UET/KLTN/papers/VTI-Project-2/MSR_data_cleaned.csv',
#  'processed_rows': 20001,
#  'kept_rows': 17341,
#  'skipped_no_label': 2659,
#  'skipped_empty_text': 0,
#  'split_sizes': {'train': 13896, 'val': 1684, 'test': 1761},
#  'label_totals': {'bypass': 772,
#   'info': 1580,
#   'dos': 11502,
#   'overflow': 5112,
#   'exec': 5539,
#   'mem': 717,
#   'priv': 346,
#   'other': 119},
#  'label_by_split': {'train': {'bypass': 619,
#    'info': 1276,
#    'dos': 9202,
#    'overflow': 4058,
#    'exec': 4429,
#    'mem': 597,
#    'priv': 274,
#    'other': 96},
#   'val': {'bypass': 74,
#    'info': 156,
#    'dos': 1139,
#    'overflow': 523,
#    'exec': 539,
#    'mem': 60,
#    'other': 13,
#    'priv': 30},
#   'test': {'bypass': 79,
#    'info': 148,
#    'dos': 1161,
#    'overflow': 531,
#    'exec': 571,
#    'mem': 60,
#    'priv': 42,
#    'other': 10}},
#  'top_raw_classifications': {'DoS': 6692,
#   'Exec Code': 1616,
#   'DoS Exec Code Overflow': 1516,
#   'DoS Overflow': 1342,
#   '+Info': 1290,
#   'DoS Exec Code': 1022,
#   'Exec Code Overflow': 849,
#   'Overflow': 828,
#   'Bypass': 676,
#   '+Priv': 269,
#   'DoS Overflow Mem. Corr.': 226,
#   'DoS Exec Code Mem. Corr.': 200,
#   'DoS Exec Code Overflow Mem. Corr.': 190,
#   'DoS +Info': 146,
#   'Dir. Trav.': 115,
#   'DoS Overflow +Info': 70,
#   'DoS Mem. Corr.': 65,
#   'Exec Code Bypass': 58,
#   'Exec Code +Priv': 42,
#   'Exec Code Overflow +Info': 39,
#   'Bypass +Info': 18,
#   'Overflow +Priv': 18,
#   'DoS Overflow +Priv Mem. Corr.': 17,
#   'Overflow Mem. Corr. +Info': 12,
#   'DoS Bypass': 9},
#  'outputs': {'dataset': '/Users/ldt/UET/KLTN/papers/VTI-Project-2/artifacts/data_sample/vti_dataset.csv.gz',
#   'train': '/Users/ldt/UET/KLTN/papers/VTI-Project-2/artifacts/data_sample/train.csv.gz',
#   'val': '/Users/ldt/UET/KLTN/papers/VTI-Project-2/artifacts/data_sample/val.csv.gz',
#   'test': '/Users/ldt/UET/KLTN/papers/VTI-Project-2/artifacts/data_sample/test.csv.gz'}}

# %%
import json
from pathlib import Path

ROOT = Path.cwd() if (Path.cwd() / "src").exists() else Path.cwd().parent
summary_path = ROOT / "artifacts" / "data_sample" / "summary.json"
print(summary_path.read_text()[:2000])
# Out:
# {
#   "kept_rows": 17341,
#   "label_by_split": {
#     "test": {
#       "bypass": 79,
#       "dos": 1161,
#       "exec": 571,
#       "info": 148,
#       "mem": 60,
#       "other": 10,
#       "overflow": 531,
#       "priv": 42
#     },
#     "train": {
#       "bypass": 619,
#       "dos": 9202,
#       "exec": 4429,
#       "info": 1276,
#       "mem": 597,
#       "other": 96,
#       "overflow": 4058,
#       "priv": 274
#     },
#     "val": {
#       "bypass": 74,
#       "dos": 1139,
#       "exec": 539,
#       "info": 156,
#       "mem": 60,
#       "other": 13,
#       "overflow": 523,
#       "priv": 30
#     }
#   },
#   "label_totals": {
#     "bypass": 772,
#     "dos": 11502,
#     "exec": 5539,
#     "info": 1580,
#     "mem": 717,
#     "other": 119,
#     "overflow": 5112,
#     "priv": 346
#   },
#   "outputs": {
#     "dataset": "/Users/ldt/UET/KLTN/papers/VTI-Project-2/artifacts/data_sample/vti_dataset.csv.gz",
#     "test": "/Users/ldt/UET/KLTN/papers/VTI-Project-2/artifacts/data_sample/test.csv.gz",
#     "train": "/Users/ldt/UET/KLTN/papers/VTI-Project-2/artifacts/data_sample/train.csv.gz",
#     "val": "/Users/ldt/UET/KLTN/papers/VTI-Project-2/artifacts/data_sample/val.csv.gz"
#   },
#   "processed_rows": 20001,
#   "raw_csv_path": "/Users/ldt/UET/KLTN/papers/VTI-Project-2/MSR_data_cleaned.csv",
#   "seed": 42,
#   "skipped_empty_text": 0,
#   "skipped_no_label": 2659,
#   "split_sizes": {
#     "test": 1761,
#     "train": 13896,
#     "val": 1684
#   },
#   "top_raw_classifications": {
#     "+Info": 1290,
#     "+Priv": 269,
#     "Bypass": 676,
#     "Bypass +Info": 18,
#     "Dir. Trav.": 115,
#     "DoS": 6692,
#     "DoS +Info": 146,
#     "DoS Bypass": 9,
#     "DoS Exec Code": 1022,
#     "DoS Exec Code Mem. Corr.": 200,
#     "DoS Exec Code Overflow": 1516,
#     "DoS Exec Code Overflow Mem. Corr.": 190,
#     "DoS Mem. Corr.": 65,
#     "DoS Overflow": 1342,
#     "DoS Overflow +Info": 70,
#     "DoS Overflow +Priv Mem. Corr.": 17,
#     "DoS Overflow Mem. Corr.": 226,
#     "Exec Code": 1616,
#     "Exec Code +Priv": 42,
#     "Exec Code Bypass": 58,
#     "Exec Code Overflow": 849
